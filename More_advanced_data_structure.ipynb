# %% [markdown]
# <a href="https://colab.research.google.com/github/paweenatoei/data_viz/blob/main/More_advanced_data_structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# หน้าตาของ list คือ ![ECF83DB3-1604-497A-9282-AB6D81B20A1F.png](data:image/png;base64,...)

# %% [markdown]
# #**Dictionary**
#
# สามารถ index ด้วยอะไรก็ได้ แต่ลำดับจะหายไป

# %%
ex_dict = {'a':10,'1':1, 'stat':5} #curly brackets ในการบอกว่าเป็น dict

# %%
ex_dict['stat']
# Out:
# 5

# %%
ex2_dict = {1:'one', 2:'two', 3:'three'}

# %%
ex2_dict[2]
# Out:
# 'two'

# %% [markdown]
# #**การเพิ่มสมาชิก**

# %%
ex2_dict[0] = 'zero'

# %%
ex2_dict
# Out:
# {0: 'zero', 1: 'one', 2: 'two', 3: 'three'}

# %% [markdown]
# # คำสั่ง
# * keys() ดูว่ามีindexอะไรบ้าง
# * values() ดูค่าของมัน

# %%
ex2_dict.keys()
# Out:
# dict_keys([1, 2, 3, 0])

# %%
for index in ex2_dict.keys() :
    print(index)
# Out:
# 1
# 2
# 3
# 0

# %%
ex2_dict.values()
# Out:
# dict_values(['one', 'two', 'three', 'zero'])

# %%
index
# Out:
# 0

# %% [markdown]
# **dict เอาไปใช้ร่วมกับ dataframe ของ pandas**

# %% [markdown]
# #**Numpy array (array n มิติ)**![47204CD6-D27D-4395-B8A6-5C3C35542FDA.png](data:image/png;base64,...)

# %% [markdown]
# numpy คือ packege ที่ทำงานเกี่ยวกับ array ของตัวเลข(ที่มีคนเขียนขึ้นมาและนิยมใช้ )
#
# numpy -> number python

# %%
import numpy #วิธีเรียกใช้งาน package

# %%
import numpy as np

# %% [markdown]
# #**สร้าง numpy array**

# %%
ex_2d_array = numpy.array([[5.2,3.0,4.5],[9.1,0.1,0.3]])
print(ex_2d_array)
# Out:
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]

# %% [markdown]
# #**การชี้ค่าใน array**

# %%
ex_2d_array[1,2]
# Out:
# 0.3

# %%
list_x = [[5.2,3.0,4.5],[9.1,0.1,0.3]] #การชี้ list
len(list_x)
# Out:
# 2

# %%
list_x[1][2]
# Out:
# 0.3

# %% [markdown]
# #**operations**

# %%
ex2_2d_array = np.array([[1,0,0],[0,0,1]])
print(ex2_2d_array)
print(ex_2d_array)
# Out:
# [[1 0 0]
#  [0 0 1]]
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]

# %%
ex_2d_array.shape #.shape ตรวจขนาดของ matrix
# Out:
# (2, 3)

# %%
ex2_2d_array + ex_2d_array
# Out:
# array([[6.2, 3. , 4.5],
#        [9.1, 0.1, 1.3]])

# %%
list_x = [[5.2,3.0,4.5],[9.1,0.1,0.3]]
list_x2 = [[1,0,0],[0,0,1]]
list_x + list_x2
# Out:
# [[5.2, 3.0, 4.5], [9.1, 0.1, 0.3], [1, 0, 0], [0, 0, 1]]

# %%
ex2_2d_array - ex_2d_array
# Out:
# array([[-4.2, -3. , -4.5],
#        [-9.1, -0.1,  0.7]])

# %%
ex2_2d_array * ex_2d_array #การคูณแบบ array เอาตำแหน่งเดียวกันมาคูณกัน
# Out:
# array([[5.2, 0. , 0. ],
#        [0. , 0. , 0.3]])

# %% [markdown]
# matrix multiplication (dot product)

# %%
print(ex_2d_array)
print(ex_2d_array.T)
# Out:
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]
# [[5.2 9.1]
#  [3.  0.1]
#  [4.5 0.3]]

# %%
dot_mat = np.dot(ex2_2d_array,ex_2d_array.T)
print(dot_mat)
# Out:
# [[5.2 9.1]
#  [4.5 0.3]]

# %%
np.linalg.det(dot_mat)
# Out:
# -39.389999999999986

# %% [markdown]
# search google -> stackoverflow หรือ web ของ package สำหรับ operation อื่นๆ

# %% [markdown]
# #**Matrix Slicing**

# %%
print(ex_2d_array)
# Out:
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]

# %%
ex_2d_array[1,1:]
# Out:
# array([0.1, 0.3])

# %%
ex_2d_array[:,:2]
# Out:
# array([[5.2, 3. ],
#        [9.1, 0.1]])

# %% [markdown]
# ##**HW5 เขียน Function คูณ matrix**
#
# แล้ว test กับ matrix
#
# * (2,3)*(3,2)
# * (4,4)*(4,1)
# * (2,2)*(2,2)
